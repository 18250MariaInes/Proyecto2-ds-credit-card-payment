# %%
import pandas as pd

# %%
df = pd.read_csv('./datafinal.csv')

# %%
df.head(17)
# Out:
#     id  limit_bal  sex  education  marriage  age  pay_sep  pay_ago  pay_jul  \
# 0    1    20000.0    1          2         0   24        2        0       -1
# 1    2   120000.0    1          2         1   26        0        0        0
# 2    3    90000.0    1          2         1   34        0        0        0
# 3    4    50000.0    1          2         0   37        0        0        0
# 4    5    50000.0    0          2         0   57        0        0       -1
# 5    6    50000.0    0          1         1   37        0        0        0
# 6    7   500000.0    0          1         1   29        0        0        0
# 7    8   100000.0    1          2         1   23        0        0       -1
# 8    9   140000.0    1          3         0   28        0        2        2
# 9   10    20000.0    0          3         1   35        0       -2        0
# 10  11   200000.0    1          3         1   34        0        2        2
# ...

# %%
df.loc[16]
# Out:
# id                       17.0
# limit_bal             20000.0
# sex                       0.0
# education                 1.0
# marriage                  1.0
# age                      24.0
# pay_sep                   0.0
# pay_ago                   2.0
# pay_jul                   2.0
# pay_jun                   2.0
# pay_may                   2.0
# pay_apr                   2.0
# bill_amt_sep          15376.0
# bill_amt_ago          18010.0
# bill_amt_jul          17428.0
# bill_amt_jun          18338.0
# bill_amt_may          17905.0
# bill_amt_apr          19104.0
# pay_amt_sep            3200.0
# pay_amt_ago               0.0
# pay_amt_jul            1500.0
# pay_amt_jun               0.0
# pay_amt_may            1650.0
# pay_amt_apr               0.0
# payment_next_month        1.0
# Name: 16, dtype: float64
